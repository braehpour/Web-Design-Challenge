# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
import scipy.stats as sts
from datetime import date
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 650

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
weather_response = requests.get(query_url)
weather_json = weather_response.json()
# print(json.dumps(weather_json, indent = 4))

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
city_count = 0

city_dict = {}
city_list = []

city_name_list = []
city_lat_list = []
city_lng_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
wind_speed_list = []
country_list = []
date_list = []



print("Beginning Data Retrieval")
print("-----------------------------")
for city in cities:
    city_count += 1
    
    if city_count <= 9:
        
        try:
            print(f'Processing Record Number 0{city_count} | {city}')
            query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()

            city_name_list.append(weather_json['name'])
            city_lat_list.append(weather_json['coord']['lat'])
            city_lng_list.append(weather_json['coord']['lon'])
            max_temp_list.append(weather_json['main']['temp_max'])
            humidity_list.append(weather_json['main']['humidity'])
            cloudiness_list.append(weather_json['clouds']['all'])
            wind_speed_list.append(weather_json['wind']['speed'])
            country_list.append(weather_json['sys']['country'])
            date_list.append(weather_json['dt'])

        except:
            print("City not found. Skipping...")
        
    else:
        try:
            print(f'Processing Record Number {city_count} | {city}')
            query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
            weather_response = requests.get(query_url)
            weather_json = weather_response.json()

            city_name_list.append(weather_json['name'])
            city_lat_list.append(weather_json['coord']['lat'])
            city_lng_list.append(weather_json['coord']['lon'])
            max_temp_list.append(weather_json['main']['temp_max'])
            humidity_list.append(weather_json['main']['humidity'])
            cloudiness_list.append(weather_json['clouds']['all'])
            wind_speed_list.append(weather_json['wind']['speed'])
            country_list.append(weather_json['sys']['country'])
            date_list.append(weather_json['dt'])

        except:
            print("City not found. Skipping...")
        
city_dict = {'City_Name': city_name_list,
                'Lat': city_lat_list, 
                'Lon': city_lng_list, 
                'Max_Temp': max_temp_list, 
                'Humidity': humidity_list,
                'Clouds': cloudiness_list,
                'Wind_Speed': wind_speed_list,
                'Country': country_list,
                'Date': date_list}
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record Number 01 | mitsamiouli
# Processing Record Number 02 | balkhash
# Processing Record Number 03 | alofi
# Processing Record Number 04 | salalah
# Processing Record Number 05 | ushuaia
# Processing Record Number 06 | seoul
# Processing Record Number 07 | araouane
# Processing Record Number 08 | daru
# Processing Record Number 09 | vengerovo
# Processing Record Number 10 | hobart
# Processing Record Number 11 | morant bay
# Processing Record Number 12 | dunedin
# Processing Record Number 13 | rio das pedras
# Processing Record Number 14 | lebu
# Processing Record Number 15 | popondetta
# Processing Record Number 16 | bredasdorp
# Processing Record Number 17 | ribeira grande
# Processing Record Number 18 | freeport
# Processing Record Number 19 | leningradskiy
# Processing Record Number 20 | kapaa
# Processing Record Number 21 | progreso
# Processing Record Number 22 | chardara
# Processing Record Number 23 | hermanus
# Processing Record Number 24 | cabedelo
# Processing Record Number 25 | bolungarvik
# City not found. Skipping...
# Processing Record Number 26 | teguise
# Processing Record Number 27 | kaitangata
# Processing Record Number 28 | mill valley
# Processing Record Number 29 | rikitea
# Processing Record Number 30 | tasiilaq
# Processing Record Number 31 | bambous virieux
# Processing Record Number 32 | pemangkat
# Processing Record Number 33 | punta arenas
# Processing Record Number 34 | atar
# Processing Record Number 35 | gizo
# Processing Record Number 36 | cabo san lucas
# Processing Record Number 37 | sao filipe
# Processing Record Number 38 | porosozero
# Processing Record Number 39 | atuona
# Processing Record Number 40 | port elizabeth
# Processing Record Number 41 | nemuro
# Processing Record Number 42 | mount isa
# Processing Record Number 43 | grand river south east
# City not found. Skipping...
# Processing Record Number 44 | jamestown
# Processing Record Number 45 | riyadh
# Processing Record Number 46 | busselton
# Processing Record Number 47 | hilo
# Processing Record Number 48 | nadym
# Processing Record Number 49 | lompoc
# Processing Record Number 50 | ugoofaaru
# Processing Record Number 51 | ixtapa
# Processing Record Number 52 | athabasca
# Processing Record Number 53 | palasa
# Processing Record Number 54 | bluff
# Processing Record Number 55 | butaritari
# Processing Record Number 56 | belle fourche
# Processing Record Number 57 | mataura
# Processing Record Number 58 | saint george
# Processing Record Number 59 | illoqqortoormiut
# City not found. Skipping...
# Processing Record Number 60 | simao
# Processing Record Number 61 | barrow
# Processing Record Number 62 | albany
# Processing Record Number 63 | kruisfontein
# Processing Record Number 64 | cape town
# Processing Record Number 65 | upernavik
# Processing Record Number 66 | east london
# Processing Record Number 67 | tingo maria
# Processing Record Number 68 | kavieng
# Processing Record Number 69 | grand centre
# City not found. Skipping...
# Processing Record Number 70 | krasnogorsk
# Processing Record Number 71 | ponta do sol
# Processing Record Number 72 | vaini
# Processing Record Number 73 | khatanga
# Processing Record Number 74 | attawapiskat
# City not found. Skipping...
# Processing Record Number 75 | kaoma
# Processing Record Number 76 | grand gaube
# Processing Record Number 77 | mafinga
# Processing Record Number 78 | mahibadhoo
# Processing Record Number 79 | umzimvubu
# City not found. Skipping...
# Processing Record Number 80 | panalingaan
# Processing Record Number 81 | asyut
# Processing Record Number 82 | baykit
# Processing Record Number 83 | yeppoon
# Processing Record Number 84 | north bend
# Processing Record Number 85 | puerto ayora
# Processing Record Number 86 | petropavlovka
# Processing Record Number 87 | kavaratti
# Processing Record Number 88 | hovd
# Processing Record Number 89 | witu
# Processing Record Number 90 | bud
# Processing Record Number 91 | namatanai
# Processing Record Number 92 | kasulu
# Processing Record Number 93 | oranjemund
# Processing Record Number 94 | tondano
# Processing Record Number 95 | tapaua
# City not found. Skipping...
# Processing Record Number 96 | georgetown
# Processing Record Number 97 | labuhan
# Processing Record Number 98 | olafsvik
# Processing Record Number 99 | champerico
# Processing Record Number 100 | port macquarie
# Processing Record Number 101 | carauari
# Processing Record Number 102 | itarema
# Processing Record Number 103 | masvingo
# Processing Record Number 104 | guaraniacu
# Processing Record Number 105 | tsihombe
# City not found. Skipping...
# Processing Record Number 106 | longhua
# Processing Record Number 107 | avarua
# Processing Record Number 108 | yellowknife
# Processing Record Number 109 | port hardy
# Processing Record Number 110 | fare
# Processing Record Number 111 | provideniya
# Processing Record Number 112 | simpang
# Processing Record Number 113 | asau
# Processing Record Number 114 | kirovskiy
# Processing Record Number 115 | beringovskiy
# Processing Record Number 116 | walvis bay
# Processing Record Number 117 | kirakira
# Processing Record Number 118 | kita
# Processing Record Number 119 | bilma
# Processing Record Number 120 | qaanaaq
# Processing Record Number 121 | marcona
# City not found. Skipping...
# Processing Record Number 122 | ardistan
# City not found. Skipping...
# Processing Record Number 123 | taveta
# Processing Record Number 124 | juneau
# Processing Record Number 125 | kieta
# Processing Record Number 126 | dashitou
# Processing Record Number 127 | kahului
# Processing Record Number 128 | pontes e lacerda
# Processing Record Number 129 | serabu
# Processing Record Number 130 | oktyabrskoye
# Processing Record Number 131 | flin flon
# Processing Record Number 132 | east wenatchee bench
# Processing Record Number 133 | bethel
# Processing Record Number 134 | nizhneyansk
# City not found. Skipping...
# Processing Record Number 135 | kendari
# Processing Record Number 136 | chokurdakh
# Processing Record Number 137 | sorland
# Processing Record Number 138 | mys shmidta
# City not found. Skipping...
# Processing Record Number 139 | yashkul
# Processing Record Number 140 | vao
# Processing Record Number 141 | kosh-agach
# Processing Record Number 142 | tuktoyaktuk
# Processing Record Number 143 | baruun-urt
# Processing Record Number 144 | cayenne
# Processing Record Number 145 | taolanaro
# City not found. Skipping...
# Processing Record Number 146 | bengkulu
# Processing Record Number 147 | dikson
# Processing Record Number 148 | ahuimanu
# Processing Record Number 149 | keti bandar
# Processing Record Number 150 | sisophon
# Processing Record Number 151 | santa maria
# Processing Record Number 152 | missungwi
# Processing Record Number 153 | geraldton
# Processing Record Number 154 | lipari
# Processing Record Number 155 | norman
# Processing Record Number 156 | spirit river
# Processing Record Number 157 | kulhudhuffushi
# Processing Record Number 158 | port alfred
# Processing Record Number 159 | mahina
# Processing Record Number 160 | kodinsk
# Processing Record Number 161 | tidore
# City not found. Skipping...
# Processing Record Number 162 | kidal
# Processing Record Number 163 | thunder bay
# Processing Record Number 164 | aklavik
# Processing Record Number 165 | ibra
# Processing Record Number 166 | arraial do cabo
# Processing Record Number 167 | makanya
# Processing Record Number 168 | peniche
# Processing Record Number 169 | luderitz
# Processing Record Number 170 | satitoa
# City not found. Skipping...
# Processing Record Number 171 | butembo
# Processing Record Number 172 | el limon
# Processing Record Number 173 | eyl
# Processing Record Number 174 | castro
# Processing Record Number 175 | luzhou
# Processing Record Number 176 | zhangye
# Processing Record Number 177 | virginia beach
# Processing Record Number 178 | lalibela
# Processing Record Number 179 | chitrakonda
# Processing Record Number 180 | port-cartier
# Processing Record Number 181 | roald
# Processing Record Number 182 | tazovskiy
# Processing Record Number 183 | havoysund
# Processing Record Number 184 | ginir
# Processing Record Number 185 | tiksi
# Processing Record Number 186 | ejea de los caballeros
# Processing Record Number 187 | kokstad
# Processing Record Number 188 | baoning
# Processing Record Number 189 | saskylakh
# Processing Record Number 190 | ponca city
# Processing Record Number 191 | lavrentiya
# Processing Record Number 192 | rongcheng
# Processing Record Number 193 | solnechnyy
# Processing Record Number 194 | new norfolk
# Processing Record Number 195 | bardiyah
# Processing Record Number 196 | chuy
# Processing Record Number 197 | winneba
# Processing Record Number 198 | vila franca do campo
# Processing Record Number 199 | hithadhoo
# Processing Record Number 200 | petropavlovsk-kamchatskiy
# Processing Record Number 201 | gwadar
# Processing Record Number 202 | constitucion
# Processing Record Number 203 | tupik
# Processing Record Number 204 | carnarvon
# Processing Record Number 205 | tomatlan
# Processing Record Number 206 | husavik
# Processing Record Number 207 | troitsko-pechorsk
# Processing Record Number 208 | havre-saint-pierre
# Processing Record Number 209 | hamilton
# Processing Record Number 210 | flinders
# Processing Record Number 211 | ewa beach
# Processing Record Number 212 | ngukurr
# City not found. Skipping...
# Processing Record Number 213 | pauini
# Processing Record Number 214 | djambala
# Processing Record Number 215 | springbok
# Processing Record Number 216 | te anau
# Processing Record Number 217 | evans
# Processing Record Number 218 | nyurba
# Processing Record Number 219 | jalu
# Processing Record Number 220 | oneonta
# Processing Record Number 221 | benguela
# Processing Record Number 222 | mirabad
# Processing Record Number 223 | vaitupu
# City not found. Skipping...
# Processing Record Number 224 | esmeraldas
# Processing Record Number 225 | saldanha
# Processing Record Number 226 | hoi an
# Processing Record Number 227 | margate
# Processing Record Number 228 | saint-philippe
# Processing Record Number 229 | westport
# Processing Record Number 230 | mount gambier
# Processing Record Number 231 | thompson
# Processing Record Number 232 | saint-joseph
# Processing Record Number 233 | xai-xai
# Processing Record Number 234 | praxedis guerrero
# Processing Record Number 235 | kollam
# Processing Record Number 236 | karratha
# Processing Record Number 237 | pamanukan
# Processing Record Number 238 | goma
# Processing Record Number 239 | halalo
# City not found. Skipping...
# Processing Record Number 240 | waconia
# Processing Record Number 241 | sitka
# Processing Record Number 242 | douentza
# Processing Record Number 243 | porto novo
# Processing Record Number 244 | conde
# Processing Record Number 245 | kismayo
# Processing Record Number 246 | suntar
# Processing Record Number 247 | san vicente
# Processing Record Number 248 | nizhnyaya omka
# Processing Record Number 249 | mersing
# Processing Record Number 250 | buala
# Processing Record Number 251 | samarai
# Processing Record Number 252 | tabiauea
# City not found. Skipping...
# Processing Record Number 253 | dolbeau
# City not found. Skipping...
# Processing Record Number 254 | bandarbeyla
# Processing Record Number 255 | ginda
# Processing Record Number 256 | mar del plata
# Processing Record Number 257 | souillac
# Processing Record Number 258 | port hawkesbury
# Processing Record Number 259 | abapo
# Processing Record Number 260 | grao mogol
# Processing Record Number 261 | yenagoa
# Processing Record Number 262 | kaeo
# Processing Record Number 263 | pochutla
# Processing Record Number 264 | korem
# Processing Record Number 265 | bubaque
# Processing Record Number 266 | high level
# Processing Record Number 267 | buzmeyin
# Processing Record Number 268 | victoria
# Processing Record Number 269 | vardo
# Processing Record Number 270 | pedra branca
# Processing Record Number 271 | moba
# Processing Record Number 272 | mehamn
# Processing Record Number 273 | san patricio
# Processing Record Number 274 | macae
# Processing Record Number 275 | majene
# Processing Record Number 276 | ulladulla
# Processing Record Number 277 | clyde river
# Processing Record Number 278 | cartagena del chaira
# Processing Record Number 279 | dori
# Processing Record Number 280 | quebec
# Processing Record Number 281 | iqaluit
# Processing Record Number 282 | amderma
# City not found. Skipping...
# Processing Record Number 283 | touros
# Processing Record Number 284 | amapa
# Processing Record Number 285 | rapid valley
# Processing Record Number 286 | burica
# City not found. Skipping...
# Processing Record Number 287 | wageningen
# Processing Record Number 288 | mana
# Processing Record Number 289 | tumannyy
# City not found. Skipping...
# Processing Record Number 290 | longyearbyen
# Processing Record Number 291 | hasaki
# Processing Record Number 292 | mushabani
# Processing Record Number 293 | gamba
# Processing Record Number 294 | dauriya
# Processing Record Number 295 | caernarfon
# Processing Record Number 296 | anloga
# Processing Record Number 297 | bathurst
# Processing Record Number 298 | novokayakent
# Processing Record Number 299 | gorontalo
# Processing Record Number 300 | rio grande
# Processing Record Number 301 | fairbanks
# Processing Record Number 302 | ancud
# Processing Record Number 303 | mahebourg
# Processing Record Number 304 | byron bay
# Processing Record Number 305 | belushya guba
# City not found. Skipping...
# Processing Record Number 306 | padang
# Processing Record Number 307 | bangalore
# Processing Record Number 308 | pangnirtung
# Processing Record Number 309 | henties bay
# Processing Record Number 310 | cherskiy
# Processing Record Number 311 | la ronge
# Processing Record Number 312 | dauphin
# Processing Record Number 313 | moses lake
# Processing Record Number 314 | hofn
# Processing Record Number 315 | yar-sale
# Processing Record Number 316 | belmonte
# Processing Record Number 317 | pisco
# Processing Record Number 318 | tuy hoa
# Processing Record Number 319 | saleaula
# City not found. Skipping...
# Processing Record Number 320 | norman wells
# Processing Record Number 321 | lakhdenpokhya
# Processing Record Number 322 | chikwawa
# Processing Record Number 323 | grindavik
# Processing Record Number 324 | sobolevo
# Processing Record Number 325 | hay river
# Processing Record Number 326 | samusu
# City not found. Skipping...
# Processing Record Number 327 | porkhov
# Processing Record Number 328 | caravelas
# Processing Record Number 329 | sebnitz
# Processing Record Number 330 | kokopo
# Processing Record Number 331 | deer lake
# Processing Record Number 332 | honningsvag
# Processing Record Number 333 | barentsburg
# City not found. Skipping...
# Processing Record Number 334 | bukama
# Processing Record Number 335 | sinnar
# Processing Record Number 336 | ponta delgada
# Processing Record Number 337 | vanimo
# Processing Record Number 338 | sentyabrskiy
# City not found. Skipping...
# Processing Record Number 339 | san isidro
# Processing Record Number 340 | sarakhs
# Processing Record Number 341 | singaparna
# Processing Record Number 342 | kysyl-syr
# Processing Record Number 343 | shubarshi
# Processing Record Number 344 | bowen
# Processing Record Number 345 | airai
# Processing Record Number 346 | rawson
# Processing Record Number 347 | port lincoln
# Processing Record Number 348 | coquimbo
# Processing Record Number 349 | loding
# Processing Record Number 350 | mandan
# Processing Record Number 351 | at-bashi
# Processing Record Number 352 | sioux lookout
# Processing Record Number 353 | klaksvik
# Processing Record Number 354 | olinda
# Processing Record Number 355 | cidreira
# Processing Record Number 356 | nikolskoye
# Processing Record Number 357 | raudeberg
# Processing Record Number 358 | dong hoi
# Processing Record Number 359 | farsala
# Processing Record Number 360 | solovetskiy
# City not found. Skipping...
# Processing Record Number 361 | fort nelson
# Processing Record Number 362 | qasigiannguit
# Processing Record Number 363 | mendahara
# City not found. Skipping...
# Processing Record Number 364 | malumfashi
# Processing Record Number 365 | ruteng
# Processing Record Number 366 | necochea
# Processing Record Number 367 | ossora
# Processing Record Number 368 | hohhot
# Processing Record Number 369 | izberbash
# Processing Record Number 370 | talnakh
# Processing Record Number 371 | katsuura
# Processing Record Number 372 | lazaro cardenas
# Processing Record Number 373 | anjiang
# Processing Record Number 374 | ilulissat
# Processing Record Number 375 | broome
# Processing Record Number 376 | nishihara
# Processing Record Number 377 | borama
# City not found. Skipping...
# Processing Record Number 378 | korla
# Processing Record Number 379 | kleck
# City not found. Skipping...
# Processing Record Number 380 | derzhavinsk
# Processing Record Number 381 | sasd
# Processing Record Number 382 | rocha
# Processing Record Number 383 | turukhansk
# Processing Record Number 384 | kinablangan
# Processing Record Number 385 | hargeysa
# Processing Record Number 386 | glenwood springs
# Processing Record Number 387 | college
# Processing Record Number 388 | malakal
# Processing Record Number 389 | yellandu
# Processing Record Number 390 | codrington
# Processing Record Number 391 | los llanos de aridane
# Processing Record Number 392 | todos santos
# Processing Record Number 393 | kristoni
# Processing Record Number 394 | blagaj
# Processing Record Number 395 | lagoa
# Processing Record Number 396 | pevek
# Processing Record Number 397 | karaul
# City not found. Skipping...
# Processing Record Number 398 | chernyshevskiy
# Processing Record Number 399 | ust-tsilma
# Processing Record Number 400 | neiafu
# Processing Record Number 401 | najran
# Processing Record Number 402 | ngunguru
# Processing Record Number 403 | petukhovo
# Processing Record Number 404 | puerto colombia
# Processing Record Number 405 | hirara
# Processing Record Number 406 | yerbogachen
# Processing Record Number 407 | ondjiva
# Processing Record Number 408 | avera
# Processing Record Number 409 | parras
# City not found. Skipping...
# Processing Record Number 410 | sun valley
# Processing Record Number 411 | obo
# Processing Record Number 412 | almaznyy
# Processing Record Number 413 | hailey
# Processing Record Number 414 | faanui
# Processing Record Number 415 | valdivia
# Processing Record Number 416 | brae
# Processing Record Number 417 | nuuk
# Processing Record Number 418 | cap-aux-meules
# Processing Record Number 419 | angol
# Processing Record Number 420 | kodiak
# Processing Record Number 421 | igarka
# Processing Record Number 422 | kamenskoye
# City not found. Skipping...
# Processing Record Number 423 | esperance
# Processing Record Number 424 | lorengau
# Processing Record Number 425 | villacarrillo
# Processing Record Number 426 | voh
# Processing Record Number 427 | rakai
# Processing Record Number 428 | basco
# Processing Record Number 429 | yazd
# Processing Record Number 430 | svirsk
# Processing Record Number 431 | dipkarpaz
# City not found. Skipping...
# Processing Record Number 432 | napier
# Processing Record Number 433 | ndele
# Processing Record Number 434 | onda
# Processing Record Number 435 | hudiksvall
# Processing Record Number 436 | bull savanna
# Processing Record Number 437 | marfino
# Processing Record Number 438 | broken hill
# Processing Record Number 439 | tashtyp
# Processing Record Number 440 | vostochnyy
# Processing Record Number 441 | alice springs
# Processing Record Number 442 | moussoro
# Processing Record Number 443 | warrington
# Processing Record Number 444 | palabuhanratu
# City not found. Skipping...
# Processing Record Number 445 | yashkino
# Processing Record Number 446 | vostok
# Processing Record Number 447 | torbay
# Processing Record Number 448 | oum hadjer
# Processing Record Number 449 | sulina
# Processing Record Number 450 | praia da vitoria
# Processing Record Number 451 | labutta
# City not found. Skipping...
# Processing Record Number 452 | puebloviejo
# Processing Record Number 453 | georgiyevka
# Processing Record Number 454 | svetlogorsk
# Processing Record Number 455 | podgornoye
# Processing Record Number 456 | udachnyy
# Processing Record Number 457 | florianopolis
# Processing Record Number 458 | plettenberg bay
# Processing Record Number 459 | ardakan
# Processing Record Number 460 | fortuna foothills
# Processing Record Number 461 | taltal
# Processing Record Number 462 | kenai
# Processing Record Number 463 | sampit
# Processing Record Number 464 | northam
# Processing Record Number 465 | nome
# Processing Record Number 466 | shimoda
# Processing Record Number 467 | ulaangom
# Processing Record Number 468 | san pedro
# Processing Record Number 469 | mentok
# City not found. Skipping...
# Processing Record Number 470 | kasempa
# Processing Record Number 471 | port moresby
# Processing Record Number 472 | kainantu
# Processing Record Number 473 | usvyaty
# Processing Record Number 474 | terrace
# Processing Record Number 475 | pirogovo
# Processing Record Number 476 | ruidoso
# Processing Record Number 477 | mopipi
# Processing Record Number 478 | lerwick
# Processing Record Number 479 | bonavista
# Processing Record Number 480 | onega
# Processing Record Number 481 | nzega
# Processing Record Number 482 | alyangula
# Processing Record Number 483 | steinbach
# Processing Record Number 484 | tiznit
# Processing Record Number 485 | comodoro rivadavia
# Processing Record Number 486 | japura
# Processing Record Number 487 | digha
# Processing Record Number 488 | meyungs
# City not found. Skipping...
# Processing Record Number 489 | coahuayana
# Processing Record Number 490 | fez
# Processing Record Number 491 | lata
# Processing Record Number 492 | half moon bay
# Processing Record Number 493 | ahipara
# Processing Record Number 494 | motozintla
# Processing Record Number 495 | vyazemskiy
# Processing Record Number 496 | diamantino
# Processing Record Number 497 | elmadag
# Processing Record Number 498 | tomino
# Processing Record Number 499 | pimentel
# Processing Record Number 500 | copiapo
# Processing Record Number 501 | azare
# Processing Record Number 502 | kaseda
# Processing Record Number 503 | tsalka
# Processing Record Number 504 | colombo
# Processing Record Number 505 | mackay
# Processing Record Number 506 | kazalinsk
# City not found. Skipping...
# Processing Record Number 507 | abnub
# Processing Record Number 508 | hualmay
# Processing Record Number 509 | vila velha
# Processing Record Number 510 | divnoye
# Processing Record Number 511 | luz
# Processing Record Number 512 | juan lacaze
# Processing Record Number 513 | atakpame
# Processing Record Number 514 | banon
# Processing Record Number 515 | miragoane
# Processing Record Number 516 | rexburg
# Processing Record Number 517 | sheffield
# Processing Record Number 518 | ust-omchug
# Processing Record Number 519 | kedrovyy
# Processing Record Number 520 | komsomolskiy
# Processing Record Number 521 | bundaberg
# Processing Record Number 522 | lixourion
# Processing Record Number 523 | hachinohe
# Processing Record Number 524 | ta khmau
# Processing Record Number 525 | turka
# Processing Record Number 526 | hobyo
# Processing Record Number 527 | lugovoy
# Processing Record Number 528 | poronaysk
# Processing Record Number 529 | pechora
# Processing Record Number 530 | sri aman
# Processing Record Number 531 | cockburn town
# Processing Record Number 532 | vila
# Processing Record Number 533 | mangrol
# Processing Record Number 534 | longyan
# Processing Record Number 535 | maragogi
# Processing Record Number 536 | dzhusaly
# City not found. Skipping...
# Processing Record Number 537 | ugep
# Processing Record Number 538 | manavalakurichi
# Processing Record Number 539 | kolpashevo
# Processing Record Number 540 | buqayq
# City not found. Skipping...
# Processing Record Number 541 | okha
# Processing Record Number 542 | pitea
# Processing Record Number 543 | san jeronimo
# Processing Record Number 544 | general pico
# Processing Record Number 545 | dujuma
# City not found. Skipping...
# Processing Record Number 546 | sambava
# Processing Record Number 547 | litovko
# Processing Record Number 548 | tuatapere
# Processing Record Number 549 | wagar
# Processing Record Number 550 | qingdao
# Processing Record Number 551 | kotri
# Processing Record Number 552 | caarapo
# Processing Record Number 553 | the valley
# Processing Record Number 554 | adrar
# Processing Record Number 555 | dawlatabad
# Processing Record Number 556 | puerto escondido
# Processing Record Number 557 | tateyama
# Processing Record Number 558 | burnie
# Processing Record Number 559 | fortuna
# Processing Record Number 560 | kindia
# Processing Record Number 561 | milkovo
# Processing Record Number 562 | yantal
# Processing Record Number 563 | uglovskoye
# Processing Record Number 564 | paamiut
# Processing Record Number 565 | gigmoto
# Processing Record Number 566 | roma
# Processing Record Number 567 | guanica
# Processing Record Number 568 | egvekinot
# Processing Record Number 569 | kuznechikha
# Processing Record Number 570 | wanning
# Processing Record Number 571 | kerteh
# City not found. Skipping...
# Processing Record Number 572 | hirado
# Processing Record Number 573 | mogadishu
# Processing Record Number 574 | sakaiminato
# Processing Record Number 575 | saint-georges
# Processing Record Number 576 | pacific grove
# Processing Record Number 577 | jadu
# Processing Record Number 578 | bucerias
# Processing Record Number 579 | hays
# Processing Record Number 580 | meulaboh
# Processing Record Number 581 | sangar
# Processing Record Number 582 | nioki
# Processing Record Number 583 | bulungu
# Processing Record Number 584 | myitkyina
# Processing Record Number 585 | vilhena
# Processing Record Number 586 | santa cruz
# Processing Record Number 587 | jaque
# Processing Record Number 588 | port hedland
# Processing Record Number 589 | bitung
# Processing Record Number 590 | tarudant
# City not found. Skipping...
# Processing Record Number 591 | smithers
# Processing Record Number 592 | nizwa
# Processing Record Number 593 | kota belud
# Processing Record Number 594 | rafai
# Processing Record Number 595 | marmora
# Processing Record Number 596 | ayia
# City not found. Skipping...
# Processing Record Number 597 | aligudarz
# Processing Record Number 598 | mamaku
# Processing Record Number 599 | krasnoselkup
# Processing Record Number 600 | kudahuvadhoo
# Processing Record Number 601 | qibili
# City not found. Skipping...
# Processing Record Number 602 | nouadhibou
# Processing Record Number 603 | batemans bay
# Processing Record Number 604 | bay city
# Processing Record Number 605 | hambantota
# Processing Record Number 606 | ukiah
# Processing Record Number 607 | george
# Processing Record Number 608 | sharjah
# Processing Record Number 609 | namibe
# Processing Record Number 610 | severo-kurilsk
# Processing Record Number 611 | sorong
# Processing Record Number 612 | hammerfest
# Processing Record Number 613 | richards bay
# Processing Record Number 614 | kasama
# Processing Record Number 615 | sao joao da barra
# Processing Record Number 616 | san antonio
# Processing Record Number 617 | yulara
# Processing Record Number 618 | lac du bonnet
# Processing Record Number 619 | lamar
# Processing Record Number 620 | louisbourg
# City not found. Skipping...
# Processing Record Number 621 | golynki
# Processing Record Number 622 | poli
# Processing Record Number 623 | ostrovnoy
# Processing Record Number 624 | laguna
# Processing Record Number 625 | koshurnikovo
# Processing Record Number 626 | ciudad bolivar
# Processing Record Number 627 | ambulu
# Processing Record Number 628 | mountain home
# Processing Record Number 629 | thinadhoo
# Processing Record Number 630 | tual
# Processing Record Number 631 | snina
# Processing Record Number 632 | iberia
# Processing Record Number 633 | shu
# Processing Record Number 634 | nelson bay
# Processing Record Number 635 | chara
# Processing Record Number 636 | san cristobal
# Processing Record Number 637 | disna
# Processing Record Number 638 | buta
# Processing Record Number 639 | julio de castilhos
# Processing Record Number 640 | muros
# Processing Record Number 641 | pemba
# Processing Record Number 642 | jerantut
# Processing Record Number 643 | omsukchan
# Processing Record Number 644 | qaqortoq
# Processing Record Number 645 | minyar
# Processing Record Number 646 | acqui terme
# Processing Record Number 647 | nabire
# Processing Record Number 648 | villarrica
# Processing Record Number 649 | mwadui
# Processing Record Number 650 | chokwe

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(city_dict)

# %%
city_df.set_index('City_Name')
# Out:
#                Lat     Lon  Max_Temp  Humidity  Clouds  Wind_Speed Country  \
# City_Name
# Mitsamiouli -11.38   43.28     79.72        82       1       11.74      KM
# Balkhash     46.84   74.98     47.21        63       0        3.94      KZ
# Alofi       -19.06 -169.92     75.20        73      75       18.34      NU
# Salalah      17.02   54.09     78.80        78      84        3.36      OM
# Ushuaia     -54.80  -68.30     44.60        70      75        5.82      AR
# ...            ...     ...       ...       ...     ...         ...     ...
# Acqui Terme  44.68    8.47     46.99        76       0        3.47      IT
# Nabire       -3.37  135.48     75.70        89     100        3.15      ID
# Villarrica  -25.75  -56.43     93.79        19       0        8.41      PY
# Mwadui       -3.55   33.60     81.39        40      90        6.24      TZ
# Chokwé      -24.53   32.98     61.77        88       0        3.47      MZ
#
#                    Date
# City_Name
# Mitsamiouli  1602534438
# Balkhash     1602534438
# Alofi        1602534438
# Salalah      1602534438
# Ushuaia      1602534438
# ...                 ...
# Acqui Terme  1602534529
# Nabire       1602534306
# Villarrica   1602534529
# Mwadui       1602534529
# Chokwé       1602534529
#
# [601 rows x 8 columns]

# %%
city_df.to_csv('city_data.csv')
city_df.to_html('city_data.html')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# checks to see if there are any cities in the list with more than 100% humidity.

extra_humid = 0

for h in city_df['Humidity']:
    if h > 100:
        extra_humid =+ 1
        
if extra_humid > 0:
    print("You need to do this step!")

else:
    print("You can skip this step!")
# Out:
# You can skip this step!

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
current_date = date.today()

# %%
lat_plot = city_df['Lat']
temp_plot = city_df['Max_Temp']

plt.scatter(lat_plot, temp_plot, edgecolor="k")
plt.title(f'City Latitude vs Maximum Temperature ({current_date})')
plt.ylabel('Max Temp (F)')
plt.xlabel('Latitude')
plt.grid(b = True, alpha = .25)
plt.savefig("../visualizations/Lat_vs_Temp.png")

# Analyzing how maximum temperature is affected by the change in latitude

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
humidity_plot = city_df['Humidity']

plt.scatter(lat_plot, humidity_plot, edgecolor="k")
plt.title(f'City Latitude vs Humidity ({current_date})')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(b = True, alpha = .25)
plt.savefig('../visualizations/Lat_vs_Humidity.png')

# Analyzing how humidity is affected by the change in latitude

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
clouds_plot = city_df['Clouds']

plt.scatter(lat_plot, clouds_plot, edgecolor="k")
plt.title(f'City Latitude vs Cloudiness ({current_date})')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(b = True, alpha = .25)
plt.savefig('../visualizations/Lat_vs_Clouds.png')

# Analyzing how cloudiness is affected by the change in latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
windSpeed_plot = city_df['Wind_Speed']

plt.scatter(lat_plot, clouds_plot, edgecolor="k")
plt.title(f'City Latitude vs Wind Speed ({current_date})')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(b = True, alpha = .25)
plt.savefig('../visualizations/Lat_vs_WindSpeed.png')

# Analyzing how cloudiness is affected by the change in latitude

# %% [markdown]
# ## Linear Regression

# %%
#Isolating the northern latitudes
lat_north = city_df.loc[city_df['Lat']>=0]
north_df = pd.DataFrame(lat_north)

# %%
#isolating the southern latitudes
lat_south = city_df.loc[city_df['Lat']<0]
south_df = pd.DataFrame(lat_south)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Max_Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.grid(b = True, alpha = .25)
plt.title(f'Northern Hemisphere - Max Temp vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)} indicating a strong negative correlation.')
# Out:
# The linear regression line equation is: y = -0.87x + 92.38.
# The correlation is: -0.84 indicating a strong negative correlation.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Max_Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Max Temp vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)} indicating a strong positive correlation.')
# Out:
# The linear regression line equation is: y = 0.54x + 80.75.
# The correlation is: 0.65 indicating a strong positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(b = True, alpha = .25)
plt.title(f'Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = 0.23x + 63.73.
# The correlation is: 0.21, which does not indicate a very strong coorelation.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = 0.15x + 74.76.
# The correlation is: 0.1, which does not indicate a very strong coorelation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Clouds']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(b = True, alpha = .25)
plt.title(f'Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which indicates there is no coorelation.')
# Out:
# The linear regression line equation is: y = 0.28x + 42.87.
# The correlation is: 0.15, which indicates there is no coorelation.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Clouds']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = 0.77x + 62.65.
# The correlation is: 0.27, which does not indicate a very strong coorelation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Wind_Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = 0.03x + 7.15.
# The correlation is: 0.1, which does not indicate a very strong coorelation.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Wind_Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolor="k")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(b = True, alpha = .25)
plt.title(f'Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression ({current_date})')
plt.show()
correlation = sts.pearsonr(x_values,y_values)
print(f'The linear regression line equation is: {line_eq}.')
print(f'The correlation is: {round(correlation[0],2)}, which does not indicate a very strong coorelation.')
# Out:
# The linear regression line equation is: y = -0.05x + 7.17.
# The correlation is: -0.14, which does not indicate a very strong coorelation.
